# %%
import numpy as np
import pandas as pd
import os
import psutil
import math

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import time
import datetime

import gc
import seaborn as sns
import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")

import scipy.signal as sg
from scipy.signal import hann
from scipy.signal import hilbert
from scipy.signal import convolve
# Out:
# c:\users\afoo0\.conda\envs\tensorflow_gpu\lib\site-packages\numpy\core\__init__.py:29: UserWarning: loaded more than 1 DLL from .libs:
# c:\users\afoo0\.conda\envs\tensorflow_gpu\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# c:\users\afoo0\.conda\envs\tensorflow_gpu\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# %%time
train = pd.read_csv('./train.csv', dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})
# Out:
# Wall time: 1min 20s

# %%
# NY_FREQ_IDX = 75000  # the test signals are 150k samples long, Nyquist is thus 75k.
# CUTOFF = 18000
# MAX_FREQ_IDX = 100000
# FREQ_STEP = 2500

# def des_bw_filter_lp(cutoff=CUTOFF):  # low pass filter
#     b, a = sg.butter(4, Wn=cutoff/NY_FREQ_IDX)
#     return b, a

# def fft_process(x):
#     xc = x.values
#     xcdm = xc - np.mean(xc)
    
# #     b, a = des_bw_filter_lp(cutoff=18000)
# #     xcz = sg.lfilter(b, a, xcdm)
    
#     zc = np.fft.fft(xcdm)
#     zc = zc[:MAX_FREQ_IDX]

#     # FFT transform values
#     realFFT = np.real(zc)
#     imagFFT = np.imag(zc)

#     return np.swapaxes([realFFT,imagFFT],0,1)

# %%
num_seg = len(train)//100000
train_X = []
train_y = []
for i in tqdm_notebook(range(num_seg)):
#     train_X.append(fft_process(train['acoustic_data'].iloc[150000 * i:150000 * i + 150000]))
    if 100000 * i + 150000 < len(train):
        train_X.append(train['acoustic_data'].iloc[100000 * i:100000 * i + 150000])
        train_y.append(train['time_to_failure'].iloc[100000 * i + 149999])
del train
gc.collect()
train_X = np.array(train_X,dtype = np.float32)
train_y = np.array(train_y,dtype = np.float32)
# Out:
# HBox(children=(IntProgress(value=0, max=6291), HTML(value='')))

# %%
X_mean = train_X.mean(0)
X_std = train_X.std(0)
train_X -= X_mean
train_X /= X_std
y_mean = train_y.mean()
y_std = train_y.std()
train_y -= y_mean
train_y /= y_std

# %%
# X_mean = train['acoustic_data'].mean()
# X_std = train['acoustic_data'].std()

# y_mean = train['time_to_failure'].mean()
# y_std = train['time_to_failure'].std()

# %%
submission = pd.read_csv('./sample_submission.csv', index_col='seg_id')
test_X = []
for i, seg_id in enumerate(tqdm_notebook(submission.index)):
    seg = pd.read_csv('./test/' + seg_id + '.csv')
    test_X.append(seg['acoustic_data'])
test_X = np.array(test_X,dtype = np.float32)
test_X -= X_mean
test_X /= X_std
# Out:
# HBox(children=(IntProgress(value=0, max=2624), HTML(value='')))

# %%
train_X = np.expand_dims(train_X,-1)
test_X = np.expand_dims(test_X,-1)

# %%
import keras
from keras.models import Model
from keras.layers import *
from keras.optimizers import Adam,SGD
from keras.backend import clear_session
import tensorflow.keras.backend as K
import tensorflow as tf

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim
# Out:
# Using TensorFlow backend.

# %%
def keras_model():
    def wave_block(x,filters,kernel_size,n):
        dilation_rates = [2**i for i in range(n)]
        x = Conv1D(filters=filters,
                    kernel_size=1, 
                    padding='same')(x)
        res_x = x
#         x_ = []
        for dilation_rate in dilation_rates:
            tanh_out = Conv1D(filters=filters,
                    kernel_size=kernel_size, 
                    padding='same',
                    activation = 'tanh',
                    dilation_rate=dilation_rate)(x)
            sigm_out = Conv1D(filters=filters,
                    kernel_size=kernel_size, 
                    padding='same',
                    activation = 'sigmoid',
                    dilation_rate=dilation_rate)(x)
            x = Multiply()([tanh_out,sigm_out])
            x = Conv1D(filters = filters,
                           kernel_size = 1,
                           padding='same')(x)
#             x = BatchNormalization()(x)
#             x = SpatialDropout1D(0.2)(x)
            res_x = Add()([res_x,x])
#             x_.append(x)
        return res_x
        
    
    clear_session()
    inp = Input(shape=(150000,1))
    Collect = []
    x = wave_block(inp,16,3,8)
    x = AveragePooling1D(10)(x)
#     x = BatchNormalization()(x)
#     x = SpatialDropout1D(0.05)(x)
    x = wave_block(x,32,3,5)
    x = AveragePooling1D(10)(x)
#     x = BatchNormalization()(x)
#     x = SpatialDropout1D(0.05)(x)
    x = wave_block(x,64,3,3)
    x = AveragePooling1D(10)(x)
#     x = BatchNormalization()(x)
#     x = SpatialDropout1D(0.05)(x)
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    x = Attention(150)(x)
#     x = Dropout(0.2)(x)
    x = Dense(128, activation="relu")(x)
    x = Dense(1)(x)
    model = Model(inputs = inp, outputs=x)
    return model
model = keras_model()

model.summary()
# SVG(model_to_dot(model).create(prog='dot', format='svg'))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 150000, 1)    0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 150000, 16)   32          input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 150000, 16)   784         conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 150000, 16)   784         conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 150000, 16)   0           conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 150000, 16)   272         multiply_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 150000, 16)   784         conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 150000, 16)   784         conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 150000, 16)   0           conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 150000, 16)   272         multiply_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 150000, 16)   784         conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 150000, 16)   784         conv1d_7[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 150000, 16)   0           conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 150000, 16)   272         multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 150000, 16)   784         conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 150000, 16)   784         conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 150000, 16)   0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 150000, 16)   272         multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 150000, 16)   784         conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 150000, 16)   784         conv1d_13[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 150000, 16)   0           conv1d_14[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 150000, 16)   272         multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 150000, 16)   784         conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 150000, 16)   784         conv1d_16[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 150000, 16)   0           conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 150000, 16)   0           conv1d_1[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 150000, 16)   272         multiply_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 150000, 16)   0           add_1[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 150000, 16)   784         conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 150000, 16)   784         conv1d_19[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 150000, 16)   0           add_2[0][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 150000, 16)   0           conv1d_20[0][0]
#                                                                  conv1d_21[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 150000, 16)   0           add_3[0][0]
#                                                                  conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 150000, 16)   272         multiply_7[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 150000, 16)   0           add_4[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 150000, 16)   784         conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 150000, 16)   784         conv1d_22[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 150000, 16)   0           add_5[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 150000, 16)   0           conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 150000, 16)   0           add_6[0][0]
#                                                                  conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 150000, 16)   272         multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 150000, 16)   0           add_7[0][0]
#                                                                  conv1d_25[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 15000, 16)    0           add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 15000, 32)    544         average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 15000, 32)    3104        conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 15000, 32)    3104        conv1d_26[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 15000, 32)    0           conv1d_27[0][0]
#                                                                  conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 15000, 32)    1056        multiply_9[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 15000, 32)    3104        conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 15000, 32)    3104        conv1d_29[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 15000, 32)    0           conv1d_30[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 15000, 32)    1056        multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 15000, 32)    3104        conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 15000, 32)    3104        conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 15000, 32)    0           conv1d_33[0][0]
#                                                                  conv1d_34[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 15000, 32)    1056        multiply_11[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 15000, 32)    3104        conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 15000, 32)    3104        conv1d_35[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 15000, 32)    0           conv1d_36[0][0]
#                                                                  conv1d_37[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 15000, 32)    0           conv1d_26[0][0]
#                                                                  conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 15000, 32)    1056        multiply_12[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 15000, 32)    0           add_9[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 15000, 32)    3104        conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 15000, 32)    3104        conv1d_38[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 15000, 32)    0           add_10[0][0]
#                                                                  conv1d_35[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 15000, 32)    0           conv1d_39[0][0]
#                                                                  conv1d_40[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 15000, 32)    0           add_11[0][0]
#                                                                  conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 15000, 32)    1056        multiply_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 15000, 32)    0           add_12[0][0]
#                                                                  conv1d_41[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 1500, 32)     0           add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 1500, 64)     2112        average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 1500, 64)     12352       conv1d_42[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 1500, 64)     12352       conv1d_42[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1500, 64)     0           conv1d_43[0][0]
#                                                                  conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 1500, 64)     4160        multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 1500, 64)     12352       conv1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 1500, 64)     12352       conv1d_45[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1500, 64)     0           conv1d_46[0][0]
#                                                                  conv1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 1500, 64)     4160        multiply_15[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 1500, 64)     12352       conv1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 1500, 64)     12352       conv1d_48[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 1500, 64)     0           conv1d_42[0][0]
#                                                                  conv1d_45[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1500, 64)     0           conv1d_49[0][0]
#                                                                  conv1d_50[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 1500, 64)     0           add_14[0][0]
#                                                                  conv1d_48[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 1500, 64)     4160        multiply_16[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 1500, 64)     0           add_15[0][0]
#                                                                  conv1d_51[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 150, 64)      0           add_16[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 150, 128)     66560       average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# attention_1 (Attention)         (None, 128)          278         bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       attention_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            129         dense_1[0][0]
# ==================================================================================================
# Total params: 223,799
# Trainable params: 223,799
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.callbacks import LearningRateScheduler,ModelCheckpoint,EarlyStopping, TensorBoard
def step_decay(epoch):
    x = 0.0005
    if epoch >= 10: x = 0.00005
    return x
lr_decay = LearningRateScheduler(step_decay)

# %%
from sklearn.model_selection import KFold
n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=True, random_state=42)
oof = np.zeros(len(train_X))
prediction = np.zeros(len(test_X))
for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_X, train_y)):
    print('working fold %d' % fold_)
    strLog = "fold {}".format(fold_)
    print(strLog)
    
    model = keras_model()

    X_tr, X_val = train_X[trn_idx], train_X[val_idx]
    y_tr, y_val = train_y[trn_idx], train_y[val_idx]

    model.compile(Adam(lr=0.0005), loss='mse', metrics=['mae'])
    tbcallback = TensorBoard(log_dir='./logs',
                         histogram_freq=0,
                         batch_size=256,
                         write_graph=True,
                         write_grads=True,
                         write_images=True,
                         embeddings_freq=0)
    model.fit(X_tr,y_tr,
             batch_size = 8,
             epochs=20,
             verbose=2,
             callbacks = [ModelCheckpoint("model.hdf5", save_best_only=True,save_weights_only = True, period=1), lr_decay, EarlyStopping(patience = 50), tbcallback],
             validation_data = (X_val,y_val)
             )
    model.load_weights("model.hdf5")
    oof[val_idx] = model.predict(X_val)[:,0]
    prediction += model.predict(test_X)[:,0] / n_fold
print("CV:",mean_absolute_error(oof,train_y))
submission['time_to_failure'] = prediction * y_std + y_mean
print(submission.head())
submission.to_csv('submission.csv')
# Out:
# working fold 0
# fold 0
# Train on 5032 samples, validate on 1258 samples
# Epoch 1/20
#  - 185s - loss: 0.6585 - mean_absolute_error: 0.6349 - val_loss: 0.5725 - val_mean_absolute_error: 0.5835
# Epoch 2/20
#  - 178s - loss: 0.5768 - mean_absolute_error: 0.5919 - val_loss: 0.5711 - val_mean_absolute_error: 0.6035
# Epoch 3/20
#  - 178s - loss: 0.5681 - mean_absolute_error: 0.5883 - val_loss: 0.5522 - val_mean_absolute_error: 0.5897
# Epoch 4/20
#  - 178s - loss: 0.5611 - mean_absolute_error: 0.5853 - val_loss: 0.5698 - val_mean_absolute_error: 0.6105
# Epoch 5/20
#  - 178s - loss: 0.5673 - mean_absolute_error: 0.5888 - val_loss: 0.5701 - val_mean_absolute_error: 0.6088
# Epoch 6/20
#  - 178s - loss: 0.5574 - mean_absolute_error: 0.5824 - val_loss: 0.5679 - val_mean_absolute_error: 0.6076
# Epoch 7/20
#  - 179s - loss: 0.5556 - mean_absolute_error: 0.5825 - val_loss: 0.5717 - val_mean_absolute_error: 0.5737
# Epoch 8/20
#  - 179s - loss: 0.5567 - mean_absolute_error: 0.5824 - val_loss: 0.5490 - val_mean_absolute_error: 0.5922
# Epoch 9/20
#  - 179s - loss: 0.5552 - mean_absolute_error: 0.5812 - val_loss: 0.5450 - val_mean_absolute_error: 0.5777
# Epoch 10/20
#  - 179s - loss: 0.5500 - mean_absolute_error: 0.5798 - val_loss: 0.5388 - val_mean_absolute_error: 0.5772
# Epoch 11/20
#  - 3568s - loss: 0.5308 - mean_absolute_error: 0.5683 - val_loss: 0.5363 - val_mean_absolute_error: 0.5783
# Epoch 12/20
#  - 178s - loss: 0.5287 - mean_absolute_error: 0.5671 - val_loss: 0.5371 - val_mean_absolute_error: 0.5720
# Epoch 13/20
#  - 178s - loss: 0.5264 - mean_absolute_error: 0.5655 - val_loss: 0.5350 - val_mean_absolute_error: 0.5742
# Epoch 14/20
#  - 179s - loss: 0.5260 - mean_absolute_error: 0.5645 - val_loss: 0.5345 - val_mean_absolute_error: 0.5749
# Epoch 15/20
#  - 179s - loss: 0.5250 - mean_absolute_error: 0.5647 - val_loss: 0.5345 - val_mean_absolute_error: 0.5712
# Epoch 16/20
#  - 180s - loss: 0.5233 - mean_absolute_error: 0.5639 - val_loss: 0.5317 - val_mean_absolute_error: 0.5704
# Epoch 17/20
#  - 179s - loss: 0.5215 - mean_absolute_error: 0.5634 - val_loss: 0.5360 - val_mean_absolute_error: 0.5685
# Epoch 18/20
#  - 179s - loss: 0.5207 - mean_absolute_error: 0.5615 - val_loss: 0.5310 - val_mean_absolute_error: 0.5671
# Epoch 19/20
#  - 179s - loss: 0.5199 - mean_absolute_error: 0.5613 - val_loss: 0.5291 - val_mean_absolute_error: 0.5705
# Epoch 20/20
#  - 180s - loss: 0.5175 - mean_absolute_error: 0.5597 - val_loss: 0.5317 - val_mean_absolute_error: 0.5774
# working fold 1
# fold 1
# Train on 5032 samples, validate on 1258 samples
# Epoch 1/20
#  - 185s - loss: 0.6537 - mean_absolute_error: 0.6356 - val_loss: 0.5739 - val_mean_absolute_error: 0.5942
# Epoch 2/20
#  - 179s - loss: 0.5763 - mean_absolute_error: 0.5936 - val_loss: 0.5578 - val_mean_absolute_error: 0.5796
# Epoch 3/20
#  - 179s - loss: 0.5717 - mean_absolute_error: 0.5920 - val_loss: 0.6512 - val_mean_absolute_error: 0.6042
# Epoch 4/20
#  - 179s - loss: 0.5606 - mean_absolute_error: 0.5844 - val_loss: 0.5564 - val_mean_absolute_error: 0.5856
# Epoch 5/20
#  - 179s - loss: 0.5558 - mean_absolute_error: 0.5831 - val_loss: 0.5787 - val_mean_absolute_error: 0.5827
# Epoch 6/20
#  - 179s - loss: 0.5564 - mean_absolute_error: 0.5831 - val_loss: 0.5540 - val_mean_absolute_error: 0.5798
# Epoch 7/20
#  - 178s - loss: 0.5532 - mean_absolute_error: 0.5821 - val_loss: 0.5517 - val_mean_absolute_error: 0.5832
# Epoch 8/20
#  - 180s - loss: 0.5580 - mean_absolute_error: 0.5858 - val_loss: 0.5573 - val_mean_absolute_error: 0.5734
# Epoch 9/20
#  - 183s - loss: 0.5438 - mean_absolute_error: 0.5767 - val_loss: 0.6097 - val_mean_absolute_error: 0.5876
# Epoch 10/20
#  - 181s - loss: 0.5445 - mean_absolute_error: 0.5774 - val_loss: 0.5605 - val_mean_absolute_error: 0.5741
# Epoch 11/20
#  - 179s - loss: 0.5272 - mean_absolute_error: 0.5653 - val_loss: 0.5411 - val_mean_absolute_error: 0.5694
# Epoch 12/20
#  - 251s - loss: 0.5234 - mean_absolute_error: 0.5644 - val_loss: 0.5410 - val_mean_absolute_error: 0.5663
# Epoch 13/20
#  - 385s - loss: 0.5219 - mean_absolute_error: 0.5639 - val_loss: 0.5371 - val_mean_absolute_error: 0.5658
# Epoch 14/20
#  - 497s - loss: 0.5214 - mean_absolute_error: 0.5632 - val_loss: 0.5352 - val_mean_absolute_error: 0.5670
# Epoch 15/20
#  - 23478s - loss: 0.5182 - mean_absolute_error: 0.5604 - val_loss: 0.5422 - val_mean_absolute_error: 0.5627
# Epoch 16/20
#  - 6249s - loss: 0.5176 - mean_absolute_error: 0.5602 - val_loss: 0.5342 - val_mean_absolute_error: 0.5624
# Epoch 17/20
#  - 3978s - loss: 0.5158 - mean_absolute_error: 0.5589 - val_loss: 0.5322 - val_mean_absolute_error: 0.5675
# Epoch 18/20
#  - 3858s - loss: 0.5154 - mean_absolute_error: 0.5588 - val_loss: 0.5337 - val_mean_absolute_error: 0.5607
# Epoch 19/20

# %%
# prediction = np.zeros(len(test_X))

# model = keras_model()

# model.compile(Adam(lr=0.00005), loss='mse', metrics=['mae'])
# model.fit(train_X,train_y,
#          batch_size = 16,
#          epochs=100,
#          verbose=2
#          )
# prediction = model.predict(test_X)[:,0]
# submission['time_to_failure'] = prediction * y_std + y_mean
# print(submission.head())
# submission.to_csv('submission.csv')

# %%
# def Generator():
#     batch_size = 32
#     while True:
#         X = []
#         Y = []
#         for i in range(batch_size):
#             while True:
#                 point = np.random.randint((len(train)-150000))
#                 seg = train.iloc[point:point+150000]
#                 if seg['time_to_failure'].values[-1] < seg['time_to_failure'].values[0]:
#                     break
#             x_raw = seg['acoustic_data']
#             x = (x_raw.values - X_mean) / X_std
#             y = seg['time_to_failure'].values[-1]
#             y = (y - y_mean) / y_std
#             X.append(x)
#             Y.append(y)
#         yield np.array(X).reshape((-1, 150000,1)),np.array(Y).reshape((-1, 1))

# %%
# prediction = np.zeros(len(test_X))
# model = keras_model()
# model.compile(Adam(lr=0.001), loss='mse', metrics=['mae'])
# model.fit_generator(Generator(),
#                      steps_per_epoch=1000,
#                      epochs=30,
#                      verbose=2
#                      )
# prediction = model.predict(test_X)[:,0]
# submission['time_to_failure'] = prediction * y_std + y_mean
# print(submission.head())
# submission.to_csv('submission.csv')
